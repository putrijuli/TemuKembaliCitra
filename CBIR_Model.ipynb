# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
os.listdir('/content/drive/My Drive/Tubes_ImageRetrieval/Dataset')
# Out:
# []

# %%
# %cd '/content/drive/My Drive/Tubes_ImageRetrieval'
# Out:
# /content/drive/My Drive/Tubes_ImageRetrieval

# %%
import numpy as np
import json
import os
import cv2
import copy
import sklearn.metrics as metric
import pandas as pd

from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint 

from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input

import matplotlib.pyplot as plt
import matplotlib

from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import *

# %%
# !pip install split-folders
import splitfolders
input_folder = "Tube_Effusion_Normal"
output = "Dataset" #where you want the split datasets saved. one will be created if it does not exist or none is set

splitfolders.ratio(input_folder, output=output, seed=42, ratio=(.8, .1, .1))
# Out:
# Requirement already satisfied: split-folders in /usr/local/lib/python3.7/dist-packages (0.4.3)
# Copying files: 457 files [00:05, 77.43 files/s]

# %%
EPOCHS = 50
INIT_LR = 1e-3
BS = 16
IMAGE_SIZE = (128, 128)
checkpoint_path = "training_1_40_subclass_cp/cp.ckpt"
feature_path = "training_1_40_subclass_feature.json"
model_path = "training_1_40_subclass_model.h5"
history_path = "training_1_40_subclass_history.json"
base_dataset = "Dataset"
class_dir = ['Normal', 'Tube', 'Effusion']

# %%
print("[INFO] indexing file images Otomatch dataset...")
type_dataset = ['val', 'train']
dataset_train = []
dataset_val = []
for type_set in type_dataset:
    for class_item in class_dir:
        cur_dir = os.path.join(base_dataset, type_set, class_item)
        for file in os.listdir(cur_dir):
            if type_set == 'train':
                dataset_train.append(os.path.join(cur_dir, file))
            else:
                dataset_val.append(os.path.join(cur_dir, file))

print("[INFO] load images Otomatch dataset...")
#  load images
train_images = []
val_images = []
for type_set in type_dataset:
    cur_dataset = dataset_train if type_set == 'train' else dataset_val
    for image_path in cur_dataset:
        if ".jpg" in image_path:
            image = cv2.imread(image_path)
            image = cv2.resize(image, IMAGE_SIZE)
            if type_set == 'train':
                train_images.append(image)
            else:
                val_images.append(image)
# Out:
# [INFO] indexing file images Otomatch dataset...
# [INFO] load images Otomatch dataset...

# %%
# normalization
print("[INFO] normalization...")
train_x = np.array(train_images).astype("float32") / 255.0
val_x = np.array(val_images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %%
class ConvAutoEncoder:
    """
    Core Convolutional AutoEncoder
    This class included with build method you can adjust of width height and depth of image
    default filters 128, and latent dimension 48
    """
    @staticmethod
    def build(width, height, depth, filters=(128,), latent_dim=48):

        input_shape = (height, width, depth)
        channel_dim = -1

        base_model = InceptionResNetV2(weights='imagenet',include_top=False,input_shape=input_shape)
        base_model.trainable = False
        inputs = base_model.input
        #x = base_model.output
        #base_model = ResNet50(weights = 'imagenet', include_top = False, input_tensor = Input(shape=(256, 256, 3)))
        #image_input = base_model.input
        #inputs = base_model.layers[-1].output
        #inputs = layers.Input(input_shape, name='anchor')

        #inputs = layers.Input(shape=input_shape)
        x = inputs
        # Encoder layer
        for f in filters:
            x = layers.Conv2D(f, (3, 3), strides=2, padding='same')(x)
            x = layers.LeakyReLU(alpha=0.2)(x)
            x = layers.BatchNormalization(axis=channel_dim, name='enc_filter_' + str(f))(x)
        volume_size = K.int_shape(x)
        x = layers.Flatten()(x)
        # Latent layer
        latent = layers.Dense(latent_dim, name="encoded")(x)
        # Decoder layer
        x = layers.Dense(np.prod(volume_size[1:]))(latent)
        x = layers.Reshape((volume_size[1], volume_size[2], volume_size[3]))(x)
        # Reverse on decoder
        for f in filters[::-1]:
            x = layers.Conv2DTranspose(f, (3, 3), strides=2, padding='same')(x)
            x = layers.LeakyReLU(alpha=0.2)(x)
            x = layers.BatchNormalization(axis=channel_dim, name='dec_filter_' + str(f))(x)
        x = layers.Conv2DTranspose(depth, (3, 3), padding="same")(x)
        outputs = layers.Activation("sigmoid", name="decoded")(x)
        #outputs = layers.Activation("softmax", name="decoded")(x)
        auto_encoder = Model(inputs, outputs, name="auto_encoder")
        return auto_encoder

# %%
print("[INFO] building auto encoder...")
auto_encoder = ConvAutoEncoder.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
opt = Adam(learning_rate=INIT_LR, decay=INIT_LR / EPOCHS)
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_loss",
    verbose = 1,
    mode='min',
    save_best_only=True)
auto_encoder.compile(loss="mse", optimizer=opt, metrics='accuracy')
auto_encoder.summary()
# Out:
# [INFO] building auto encoder...
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# Model: "auto_encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  conv2d_1427 (Conv2D)        (None, 64, 64, 128)       3584
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 64, 64, 128)       0
#
#  enc_filter_128 (BatchNormal  (None, 64, 64, 128)      512
#  ization)
#
#  flatten_6 (Flatten)         (None, 524288)            0
#
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
#  encoded (Dense)             (None, 48)                25165872
#
#  dense_6 (Dense)             (None, 524288)            25690112
#
#  reshape_6 (Reshape)         (None, 64, 64, 128)       0
#
#  conv2d_transpose_12 (Conv2D  (None, 128, 128, 128)    147584
#  Transpose)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 128, 128, 128)     0
#
#  dec_filter_128 (BatchNormal  (None, 128, 128, 128)    512
#  ization)
#
#  conv2d_transpose_13 (Conv2D  (None, 128, 128, 3)      3459
#  Transpose)
#
#  decoded (Activation)        (None, 128, 128, 3)       0
#
# =================================================================
# Total params: 51,011,635
# Trainable params: 51,011,123
# Non-trainable params: 512
# _________________________________________________________________
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay

# %%
# train the convolutional auto encoder
print("[INFO] training auto encoder...")
H = auto_encoder.fit(
    train_x, train_x,
    shuffle=True,
    validation_data=(val_x, val_x),
    epochs=EPOCHS,
    callbacks = [checkpoint_callback], batch_size=BS)
# Out:
# [INFO] training auto encoder...
# Epoch 1/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.4786
# Epoch 00001: val_loss improved from inf to 0.08872, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 69s 3s/step - loss: 0.0673 - accuracy: 0.4786 - val_loss: 0.0887 - val_accuracy: 0.5823
# Epoch 2/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0332 - accuracy: 0.6737
# Epoch 00002: val_loss improved from 0.08872 to 0.05152, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 69s 3s/step - loss: 0.0332 - accuracy: 0.6737 - val_loss: 0.0515 - val_accuracy: 0.8169
# Epoch 3/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.7893
# Epoch 00003: val_loss improved from 0.05152 to 0.04173, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 70s 3s/step - loss: 0.0248 - accuracy: 0.7893 - val_loss: 0.0417 - val_accuracy: 0.8519
# Epoch 4/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.8228
# Epoch 00004: val_loss did not improve from 0.04173
# 23/23 [==============================] - 66s 3s/step - loss: 0.0207 - accuracy: 0.8228 - val_loss: 0.0421 - val_accuracy: 0.8605
# Epoch 5/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.7945
# Epoch 00005: val_loss did not improve from 0.04173
# 23/23 [==============================] - 65s 3s/step - loss: 0.0184 - accuracy: 0.7945 - val_loss: 0.0445 - val_accuracy: 0.8614
# Epoch 6/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.8174
# Epoch 00006: val_loss improved from 0.04173 to 0.04125, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 67s 3s/step - loss: 0.0158 - accuracy: 0.8174 - val_loss: 0.0413 - val_accuracy: 0.8589
# Epoch 7/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.8136
# Epoch 00007: val_loss improved from 0.04125 to 0.03845, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 69s 3s/step - loss: 0.0147 - accuracy: 0.8136 - val_loss: 0.0385 - val_accuracy: 0.8585
# Epoch 8/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.8289
# Epoch 00008: val_loss did not improve from 0.03845
# 23/23 [==============================] - 66s 3s/step - loss: 0.0130 - accuracy: 0.8289 - val_loss: 0.0408 - val_accuracy: 0.8582
# Epoch 9/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.8397
# Epoch 00009: val_loss did not improve from 0.03845
# 23/23 [==============================] - 64s 3s/step - loss: 0.0116 - accuracy: 0.8397 - val_loss: 0.0394 - val_accuracy: 0.8582
# Epoch 10/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.8419
# Epoch 00010: val_loss improved from 0.03845 to 0.03653, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 67s 3s/step - loss: 0.0112 - accuracy: 0.8419 - val_loss: 0.0365 - val_accuracy: 0.8596
# Epoch 11/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.8445
# Epoch 00011: val_loss improved from 0.03653 to 0.03226, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 68s 3s/step - loss: 0.0102 - accuracy: 0.8445 - val_loss: 0.0323 - val_accuracy: 0.8595
# Epoch 12/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.8407
# Epoch 00012: val_loss improved from 0.03226 to 0.03088, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 69s 3s/step - loss: 0.0099 - accuracy: 0.8407 - val_loss: 0.0309 - val_accuracy: 0.8613
# Epoch 13/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.8442
# Epoch 00013: val_loss improved from 0.03088 to 0.02883, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 69s 3s/step - loss: 0.0100 - accuracy: 0.8442 - val_loss: 0.0288 - val_accuracy: 0.8620
# Epoch 14/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.8435
# Epoch 00014: val_loss improved from 0.02883 to 0.02410, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 70s 3s/step - loss: 0.0091 - accuracy: 0.8435 - val_loss: 0.0241 - val_accuracy: 0.8616
# Epoch 15/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.8512
# Epoch 00015: val_loss improved from 0.02410 to 0.02237, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 69s 3s/step - loss: 0.0080 - accuracy: 0.8512 - val_loss: 0.0224 - val_accuracy: 0.8617
# Epoch 16/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.8473
# Epoch 00016: val_loss improved from 0.02237 to 0.01997, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 70s 3s/step - loss: 0.0083 - accuracy: 0.8473 - val_loss: 0.0200 - val_accuracy: 0.8643
# Epoch 17/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.8485
# Epoch 00017: val_loss improved from 0.01997 to 0.01926, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 70s 3s/step - loss: 0.0077 - accuracy: 0.8485 - val_loss: 0.0193 - val_accuracy: 0.8618
# Epoch 18/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.8468
# Epoch 00018: val_loss did not improve from 0.01926
# 23/23 [==============================] - 67s 3s/step - loss: 0.0078 - accuracy: 0.8468 - val_loss: 0.0206 - val_accuracy: 0.8610
# Epoch 19/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.8479
# Epoch 00019: val_loss did not improve from 0.01926
# 23/23 [==============================] - 64s 3s/step - loss: 0.0083 - accuracy: 0.8479 - val_loss: 0.0215 - val_accuracy: 0.8483
# Epoch 20/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.8462
# Epoch 00020: val_loss improved from 0.01926 to 0.01396, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 71s 3s/step - loss: 0.0076 - accuracy: 0.8462 - val_loss: 0.0140 - val_accuracy: 0.8569
# Epoch 21/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.8520
# Epoch 00021: val_loss improved from 0.01396 to 0.01283, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 69s 3s/step - loss: 0.0076 - accuracy: 0.8520 - val_loss: 0.0128 - val_accuracy: 0.8534
# Epoch 22/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.8430
# Epoch 00022: val_loss improved from 0.01283 to 0.01273, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 70s 3s/step - loss: 0.0069 - accuracy: 0.8430 - val_loss: 0.0127 - val_accuracy: 0.8603
# Epoch 23/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.8528
# Epoch 00023: val_loss improved from 0.01273 to 0.01226, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 70s 3s/step - loss: 0.0064 - accuracy: 0.8528 - val_loss: 0.0123 - val_accuracy: 0.8639
# Epoch 24/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.8537
# Epoch 00024: val_loss improved from 0.01226 to 0.01163, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 70s 3s/step - loss: 0.0063 - accuracy: 0.8537 - val_loss: 0.0116 - val_accuracy: 0.8625
# Epoch 25/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.8550
# Epoch 00025: val_loss did not improve from 0.01163
# 23/23 [==============================] - 67s 3s/step - loss: 0.0065 - accuracy: 0.8550 - val_loss: 0.0133 - val_accuracy: 0.8578
# Epoch 26/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.8540
# Epoch 00026: val_loss did not improve from 0.01163
# 23/23 [==============================] - 65s 3s/step - loss: 0.0051 - accuracy: 0.8540 - val_loss: 0.0131 - val_accuracy: 0.8440
# Epoch 27/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.8591
# Epoch 00027: val_loss improved from 0.01163 to 0.01077, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 68s 3s/step - loss: 0.0053 - accuracy: 0.8591 - val_loss: 0.0108 - val_accuracy: 0.8522
# Epoch 28/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.8556
# Epoch 00028: val_loss did not improve from 0.01077
# 23/23 [==============================] - 67s 3s/step - loss: 0.0062 - accuracy: 0.8556 - val_loss: 0.0117 - val_accuracy: 0.8463
# Epoch 29/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.8462
# Epoch 00029: val_loss did not improve from 0.01077
# 23/23 [==============================] - 64s 3s/step - loss: 0.0068 - accuracy: 0.8462 - val_loss: 0.0123 - val_accuracy: 0.8566
# Epoch 30/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.8547
# Epoch 00030: val_loss did not improve from 0.01077
# 23/23 [==============================] - 64s 3s/step - loss: 0.0052 - accuracy: 0.8547 - val_loss: 0.0122 - val_accuracy: 0.8498
# Epoch 31/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.8525
# Epoch 00031: val_loss improved from 0.01077 to 0.01067, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 67s 3s/step - loss: 0.0055 - accuracy: 0.8525 - val_loss: 0.0107 - val_accuracy: 0.8348
# Epoch 32/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.8602
# Epoch 00032: val_loss did not improve from 0.01067
# 23/23 [==============================] - 67s 3s/step - loss: 0.0055 - accuracy: 0.8602 - val_loss: 0.0110 - val_accuracy: 0.8441
# Epoch 33/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.8541
# Epoch 00033: val_loss did not improve from 0.01067
# 23/23 [==============================] - 64s 3s/step - loss: 0.0051 - accuracy: 0.8541 - val_loss: 0.0132 - val_accuracy: 0.8439
# Epoch 34/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.8611
# Epoch 00034: val_loss improved from 0.01067 to 0.01063, saving model to training_1_40_subclass_cp/cp.ckpt
# 23/23 [==============================] - 67s 3s/step - loss: 0.0049 - accuracy: 0.8611 - val_loss: 0.0106 - val_accuracy: 0.8522
# Epoch 35/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.8591
# Epoch 00035: val_loss did not improve from 0.01063
# 23/23 [==============================] - 67s 3s/step - loss: 0.0044 - accuracy: 0.8591 - val_loss: 0.0110 - val_accuracy: 0.8251
# Epoch 36/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.8603
# Epoch 00036: val_loss did not improve from 0.01063
# 23/23 [==============================] - 64s 3s/step - loss: 0.0046 - accuracy: 0.8603 - val_loss: 0.0112 - val_accuracy: 0.8563
# Epoch 37/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.8638
# Epoch 00037: val_loss did not improve from 0.01063
# 23/23 [==============================] - 64s 3s/step - loss: 0.0044 - accuracy: 0.8638 - val_loss: 0.0122 - val_accuracy: 0.8500
# Epoch 38/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.8656
# Epoch 00038: val_loss did not improve from 0.01063
# 23/23 [==============================] - 64s 3s/step - loss: 0.0047 - accuracy: 0.8656 - val_loss: 0.0126 - val_accuracy: 0.8477
# Epoch 39/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.8640
# Epoch 00039: val_loss did not improve from 0.01063
# 23/23 [==============================] - 65s 3s/step - loss: 0.0046 - accuracy: 0.8640 - val_loss: 0.0114 - val_accuracy: 0.8448
# Epoch 40/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.8610
# Epoch 00040: val_loss did not improve from 0.01063
# 23/23 [==============================] - 64s 3s/step - loss: 0.0036 - accuracy: 0.8610 - val_loss: 0.0113 - val_accuracy: 0.8378
# Epoch 41/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.8665
# Epoch 00041: val_loss did not improve from 0.01063
# 23/23 [==============================] - 65s 3s/step - loss: 0.0043 - accuracy: 0.8665 - val_loss: 0.0111 - val_accuracy: 0.8427
# Epoch 42/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.8645
# Epoch 00042: val_loss did not improve from 0.01063
# 23/23 [==============================] - 65s 3s/step - loss: 0.0039 - accuracy: 0.8645 - val_loss: 0.0117 - val_accuracy: 0.8014
# Epoch 43/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.8578
# Epoch 00043: val_loss did not improve from 0.01063
# 23/23 [==============================] - 65s 3s/step - loss: 0.0039 - accuracy: 0.8578 - val_loss: 0.0120 - val_accuracy: 0.8342
# Epoch 44/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.8675
# Epoch 00044: val_loss did not improve from 0.01063
# 23/23 [==============================] - 65s 3s/step - loss: 0.0046 - accuracy: 0.8675 - val_loss: 0.0123 - val_accuracy: 0.8398
# Epoch 45/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.8683
# Epoch 00045: val_loss did not improve from 0.01063
# 23/23 [==============================] - 65s 3s/step - loss: 0.0053 - accuracy: 0.8683 - val_loss: 0.0123 - val_accuracy: 0.8326
# Epoch 46/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.8598
# Epoch 00046: val_loss did not improve from 0.01063
# 23/23 [==============================] - 69s 3s/step - loss: 0.0045 - accuracy: 0.8598 - val_loss: 0.0128 - val_accuracy: 0.8475
# Epoch 47/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.8647
# Epoch 00047: val_loss did not improve from 0.01063
# 23/23 [==============================] - 65s 3s/step - loss: 0.0037 - accuracy: 0.8647 - val_loss: 0.0107 - val_accuracy: 0.8449
# Epoch 48/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.8679
# Epoch 00048: val_loss did not improve from 0.01063
# 23/23 [==============================] - 65s 3s/step - loss: 0.0032 - accuracy: 0.8679 - val_loss: 0.0111 - val_accuracy: 0.8313
# Epoch 49/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.8673
# Epoch 00049: val_loss did not improve from 0.01063
# 23/23 [==============================] - 65s 3s/step - loss: 0.0030 - accuracy: 0.8673 - val_loss: 0.0111 - val_accuracy: 0.8307
# Epoch 50/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.8629
# Epoch 00050: val_loss did not improve from 0.01063
# 23/23 [==============================] - 65s 3s/step - loss: 0.0034 - accuracy: 0.8629 - val_loss: 0.0110 - val_accuracy: 0.8394

# %%
with open(history_path, 'w') as f:
    json.dump(H.history, f)
auto_encoder.save(model_path)

# %%
reconstruction_mse = auto_encoder.evaluate(val_x, val_x, verbose=0)
print("Convolutional autoencoder MSE:", reconstruction_mse)
print("Test Loss:", reconstruction_mse[0])
print("Test Accuracy:", reconstruction_mse[1])
# Out:
# Convolutional autoencoder MSE: [0.011020749807357788, 0.83941650390625]
# Test Loss: 0.011020749807357788
# Test Accuracy: 0.83941650390625

# %%
auto_encoder = ConvAutoEncoder.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
# load our auto_encoder from disk
print("[INFO] loading auto encoder model...")
auto_encoder.load_weights(checkpoint_path)

# create the encoder model which consists of *just* the encoder
# portion of the auto encoder
encoder = Model(inputs=auto_encoder.input, outputs=auto_encoder.get_layer("encoded").output)

# quantify the contents of our input images using the encoder
print("[INFO] encoding images...")
features = encoder.predict(train_x)
# Out:
# [INFO] loading auto encoder model...
# [INFO] encoding images...

# %%
indexes = list(range(0, train_x.shape[0]))
features_array = [[float(x) for x in y] for y in features]
labels = [path.split("/")[2] for path in dataset_train]
data = {"indexes": indexes, "features": features_array, "locations": dataset_train, "labels":labels}

# %%
with open(feature_path, 'w') as f:
    json.dump(data, f)

# %%
def euclidean(a, b):
	# compute and return the euclidean distance between two vectors
	return np.linalg.norm(a - b)

# %%
def perform_search(query_features, indexed_train, max_results=5):
	retrieved = []
	for idx in range(0, len(indexed_train["features"])):
		distance = euclidean(query_features, indexed_train["features"][idx])
		retrieved.append((distance, idx))
	retrieved = sorted(retrieved)[:max_results]
	return retrieved

# %%
print("[INFO] indexing file images Otomatch dataset...")
# indexing file images
dataset = []
for class_item in class_dir:
    cur_dir = os.path.join(base_dataset, 'test', class_item)
    for file in os.listdir(cur_dir):
        dataset.append(os.path.join(cur_dir, file))
print("test len to retrieving:", len(dataset))
print("[INFO] load test images Otomatch dataset...")
#  load images
images = []
for image_path in dataset:
    if ".jpg" in image_path:
        image = cv2.imread(image_path)
        image = cv2.resize(image, IMAGE_SIZE)
        images.append(image)
# Out:
# [INFO] indexing file images Otomatch dataset...
# test len to retrieving: 47
# [INFO] load test images Otomatch dataset...

# %%
# normalization
print("[INFO] normalization...")
test_x = np.array(images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %%
auto_encoder = ConvAutoEncoder.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
# load our auto_encoder from disk
print("[INFO] loading auto encoder model...")
auto_encoder.load_weights(checkpoint_path)
with open(feature_path) as f:
  training_indexed = json.load(f)

# create the encoder model which consists of *just* the encoder
# portion of the auto encoder
encoder = Model(inputs=auto_encoder.input,
	outputs=auto_encoder.get_layer("encoded").output)

# quantify the contents of our input images using the encoder
print("[INFO] encoding images...")
features_retrieved = encoder.predict(test_x)
# Out:
# [INFO] loading auto encoder model...
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-5.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-5.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-6.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-5.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-5.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-6.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-6.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# [INFO] encoding images...

# %%
query_indexes = list(range(0, test_x.shape[0]))
label_builder = list(np.unique(training_indexed["labels"]))
class_builder = {label_unique:[] for label_unique in label_builder}
recalls = copy.deepcopy(class_builder)
precisions = copy.deepcopy(class_builder)
accuracies = copy.deepcopy(class_builder)
# loop over the testing indexes
for i in query_indexes:
    queryFeatures = features_retrieved[i]
    results = perform_search(queryFeatures, training_indexed, max_results=5)
    labels_ret = [training_indexed["labels"][r[1]] for r in results]
    label_true = dataset[i].split("/")[2]
    label_trues = [label_true for _ in labels_ret]
    recall = metric.recall_score(label_trues, labels_ret, average='weighted')
    precision = metric.precision_score(label_trues, labels_ret, average='weighted')
    accuracy = metric.accuracy_score(label_trues, labels_ret)
    recalls[label_true].append(recall)
    precisions[label_true].append(precision)
    accuracies[label_true].append(accuracy)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("recall values:")
comb_recall, comb_precision = [], []
for key in recalls.keys():
    average_val = np.average(recalls[key])
    print(key, average_val)
    comb_recall.append(average_val)
print("combined recall", np.average(comb_recall))

print("\nprecision values:")
for key in precisions.keys():
    average_val = np.average(precisions[key])
    print(key, average_val)
    comb_precision.append(average_val)
print("combined precision", np.average(comb_precision))
# Out:
# recall values:
# Effusion 0.4666666666666667
# Normal 0.7777777777777778
# Tube 0.5454545454545454
# combined recall 0.5966329966329966
#
# precision values:
# Effusion 0.7222222222222222
# Normal 1.0
# Tube 0.8181818181818182
# combined precision 0.8468013468013469

# %%
print("\naccuracy values:")
comb_accuracy = []
for key in accuracies.keys():
    average_val = np.average(accuracies[key])
    print(key, average_val)
    comb_accuracy.append(average_val)
print("combined accuracy", np.average(comb_accuracy))
# Out:
# accuracy values:
# Effusion 0.4666666666666667
# Normal 0.7777777777777778
# Tube 0.5454545454545454
# combined accuracy 0.5966329966329966

# %%
def build_montages(image_list, image_shape, montage_shape):
    if len(image_shape) != 2:
        raise Exception('image shape must be list or tuple of length 2 (rows, cols)')
    if len(montage_shape) != 2:
        raise Exception('montage shape must be list or tuple of length 2 (rows, cols)')
    image_montages = []
    # start with black canvas to draw images onto
    montage_image = np.zeros(shape=(image_shape[1] * (montage_shape[1]), image_shape[0] * montage_shape[0], 3),
                          dtype=np.uint8)
    cursor_pos = [0, 0]
    start_new_img = False
    for img in image_list:
        if type(img).__module__ != np.__name__:
            raise Exception('input of type {} is not a valid numpy array'.format(type(img)))
        start_new_img = False
        img = cv2.resize(img, image_shape)
        # draw image to black canvas
        montage_image[cursor_pos[1]:cursor_pos[1] + image_shape[1], cursor_pos[0]:cursor_pos[0] + image_shape[0]] = img
        cursor_pos[0] += image_shape[0]  # increment cursor x position
        if cursor_pos[0] >= montage_shape[0] * image_shape[0]:
            cursor_pos[1] += image_shape[1]  # increment cursor y position
            cursor_pos[0] = 0
            if cursor_pos[1] >= montage_shape[1] * image_shape[1]:
                cursor_pos = [0, 0]
                image_montages.append(montage_image)
                # reset black canvas
                montage_image = np.zeros(shape=(image_shape[1] * (montage_shape[1]), image_shape[0] * montage_shape[0], 3),
                                      dtype=np.uint8)
                start_new_img = True
    if start_new_img is False:
        image_montages.append(montage_image)  # add unfinished montage
    return image_montages

# %%
from PIL import Image

#fig, ax = plt.subplots(nrows=2,figsize=(10,10))
queryIdx = 2 # Input Index for which images 

queryFeatures = features_retrieved[queryIdx]
results = perform_search(queryFeatures, training_indexed, max_results=5)

imgs = []
result_path = []

# loop over the results
for (d, j) in results:
    img = np.array(Image.open(dataset_train[j]))
    result_path.append(dataset_train[j])
    imgs.append(img)

# display the query image
plt.title(dataset[queryIdx])
plt.imshow(np.array(Image.open(dataset[queryIdx])))

# build a montage from the results and display it
#montage = build_montages(imgs, (512, 512), (5, 2))[0]
#ax[1].imshow(montage)

plt.figure(figsize=(30,30))
columns = 5
for i, image in enumerate(imgs):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.title(result_path[i])
    plt.imshow(image)

# %%
queryIdx = 3 # Input Index for which images 
plt.figure(figsize=(6, 6))
plt.imshow(test_x[3])
plt.title(dataset[3])
plt.show()

queryFeatures = features_retrieved[queryIdx]
results = perform_search(queryFeatures, training_indexed, max_results=5)
labels_ret = [training_indexed["labels"][r[1]] for r in results]

i = 0
f, axs = plt.subplots(1, 5)
f.set_figheight(20)
f.set_figwidth(30)
for label in labels_ret:
    #axs[i].imshow(dataset_train[results[i][1]])
    axs[i].imshow(np.array(Image.open(dataset_train[results[i][1]])))
    axs[i].set_xlabel(label.upper())
    i += 1
plt.show()
